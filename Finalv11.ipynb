# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U ultralytics

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

# %%
model = YOLO('yolo11n.pt')
model.train(data='/content/drive/MyDrive/Model/Dataset/KIIT-MiTA/kiit.yaml', epochs=200, name='kiit200', resume=False)
# Out:
# Ultralytics 8.3.185 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls runs/detect/
# !ls runs/detect/kiit2008
# Out:
# kiit200  kiit2002  kiit2003  kiit2004  kiit2005  kiit2006  kiit2007  kiit2008
# args.yaml			 labels.jpg	       train_batch2.jpg
# BoxF1_curve.png			 results.csv	       val_batch0_labels.jpg
# BoxP_curve.png			 results.png	       val_batch0_pred.jpg
# BoxPR_curve.png			 train_batch0.jpg      val_batch1_labels.jpg
# BoxR_curve.png			 train_batch16150.jpg  val_batch1_pred.jpg
# confusion_matrix_normalized.png  train_batch16151.jpg  val_batch2_labels.jpg
# confusion_matrix.png		 train_batch16152.jpg  val_batch2_pred.jpg
# labels_correlogram.jpg		 train_batch1.jpg      weights

# %%
Image(filename='runs/detect/kiit2008/results.png')

# %%
from IPython.display import Image

# Show the F1-Confidence Curve
Image(filename='runs/detect/kiit2008/BoxF1_curve.png')

# %%
from IPython.display import Image

# Show the Confusion Matrix
Image(filename='runs/detect/kiit2008/confusion_matrix.png')

# %%
from IPython.display import Image

# Show the Normalized Confusion Matrix
Image(filename='runs/detect/kiit2008/confusion_matrix_normalized.png')

# %%
from IPython.display import Image

# Show the Precision-confidence curve
Image(filename='runs/detect/kiit2008/BoxP_curve.png')

# %%
from IPython.display import Image

# Show the Recall-Confidence curve
Image(filename='runs/detect/kiit2008/BoxR_curve.png')

# %%
from IPython.display import Image

# Show the Precision-Recall curve
Image(filename='runs/detect/kiit2008/BoxPR_curve.png')

# %%
model.predict(
    source='/content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images',
    save=True,
    name='kiit2003_test',  # to avoid overwriting
    conf=0.25
)
# Out:
# image 1/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1006.jpeg: 640x608 1 Artilary, 48.3ms
# image 2/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1018.jpeg: 640x640 1 Missile, 2 Tanks, 42.7ms
# image 3/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1020.jpeg: 640x640 4 Tanks, 2 Vehicles, 11.2ms
# image 4/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1025.jpeg: 384x640 1 M. Rocket Launcher, 1 Soldier, 1 Vehicle, 81.6ms
# image 5/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1043.jpeg: 640x640 1 Tank, 14.2ms
# image 6/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_105.jpeg: 448x640 1 Missile, 12 Soldiers, 2 Tanks, 4 Vehicles, 73.2ms
# image 7/170 /content/drive/MyDrive/Model/Dataset/KIIT-MiTA/test/images/image_s3r2_kiit_1061.jpeg: 352x640 1 M. Rocket Launcher, 56.7ms
# ...

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

result_dir = 'runs/detect/kiit2003_test'
image_files = sorted([f for f in os.listdir(result_dir) if f.endswith('.jpg')])

num_images = 25
rows, cols = 9, 3

plt.figure(figsize=(15, 45))

for i in range(num_images):
    img_path = os.path.join(result_dir, image_files[i])
    img = mpimg.imread(img_path)

    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Image {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import files

# !cp runs/detect/kiit2008/weights/best.pt kiitv11.pt

# Download the model
files.download('kiitv11.pt')
